# %% [markdown]
# # Image and Multiple Bounding Boxes Augmentation for Deep Learning
#
# ## Problem at hand
# Say we have images for training our Deep Neural Network. We also have separate PASCAL VOC format XML files with coordinates of bounding boxes for objects we are going to train our model to detect.
# We want to use [TensorFlow Object Detection API](https://github.com/tensorflow/models/tree/master/research/object_detection).
# To do so we are planning to:
# 1. Convert all XML files into one CSV file that we can feed into TensorFlow Object Detection API
# 2. Resize all images together with the corresponding object bounding boxes
# 3. Augment images to upsample our dataset. Corresponding object bounding boxes should be augmented accordingly
# 4. Document augmented images' new sizes and bounding boxes' coordinates to a CSV file
#
# This tutorial will walk you through this process step by step.
#
# ## Solution
#
# At the core of this tutorial we will use amazing [imgaug library](https://github.com/aleju/imgaug). Author has published [tutorials](https://nbviewer.jupyter.org/github/aleju/imgaug-doc/tree/master/notebooks/) on the use of the library and [Documentation](https://imgaug.readthedocs.io/en/latest/index.html) is available as well.
#
# But here's a problem:
# I had to spend a whole day digging through the Documentation and coding up the script for my problem.
# I decided to share it, so you don't have to waste your time.
#
# The easiest way to install imgaug is through Anaconda. Follow this steps in Anaconda prompt to create a virtual environment, install imgaug and activate the environment:
# ```
# conda create -n myenv python=3.5.6
# conda config --add channels conda-forge
# conda install imgaug
# conda activate myenv
# ```
# You can refer to [imgaug library GitHub page](https://github.com/aleju/imgaug) for additional info on installation. To work through this tutorial you would need pandas installed as well. If you work through Anaconda it is installed by default.

# %%
# we will import all required libraries for this tutorial in advance

import imgaug as ia
ia.seed(1)
# imgaug uses matplotlib backend for displaying images
# %matplotlib inline
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage
from imgaug import augmenters as iaa 
# imageio library will be used for image input/output
import imageio
import pandas as pd
import numpy as np
import re
import os
import glob
import random
# this library is needed to read XML files for converting it into CSV
import xml.etree.ElementTree as ET
import shutil
from tqdm import tqdm

# %%
img_src = '../images_src'
lbl_src = '../labels_src.csv'

aug_des = '../images_augmented'

all_img = '../images_combined/'
all_lbl = '../labels_combined.csv'

n_aug   = 10

if not os.path.exists(aug_des):
    os.mkdir(aug_des)

if not os.path.exists(all_img):
    os.mkdir(all_img)

# %% [markdown]
# ## The data: images, XML files, bounding boxes
#
# Let's have a look at data we have. You can see basic operations of imgaug library for image loading and augmentation in this [notebook](https://nbviewer.jupyter.org/github/aleju/imgaug-doc/blob/master/notebooks/A01%20-%20Load%20and%20Augment%20an%20Image.ipynb).

# %%
# load images as NumPy arrays and append them to images list
images_file = glob.glob('{}/*.jpg'.format(img_src))

images = []
for index, file in enumerate(images_file):
    images.append(imageio.imread(file))
    print('Image {} have size of {}'.format(file, images[index].shape))
    
# how many images we have
print('We have {} images'.format(len(images)))
# Out:
# Image ../images_src/straight_my_photo-100.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_71.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_138.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-109.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-81.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-57.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-174.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-70.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_27.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-179.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-146.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-48.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-21.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-157.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-23.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_55.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-159.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-28.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-111.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-7.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-76.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-73.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_70.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-46.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-9.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-59.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-107.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-51.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-10.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-170.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-153.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-79.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-37.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-161.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-27.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-164.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-36.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-81.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-166.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-47.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-160.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-101.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_174.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-10.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-80.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-107.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-103.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-41.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-82.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-96.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-125.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-129.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-178.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_62.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_6.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-65.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_131.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-54.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-27.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-106.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_170.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_187.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-194.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_89.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-150.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-93.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-22.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-42.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_104.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-193.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-117.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-69.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-181.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-133.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-56.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_163.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_192.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-29.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_184.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-113.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_153.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-154.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_10.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-103.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-198.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-49.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_5.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_134.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-120.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-8.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_135.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-6.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-165.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_63.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_90.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-45.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-20.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-127.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_176.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-184.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-67.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_154.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-15.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_162.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-102.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-183.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-112.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_68.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-56.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-44.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-139.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-179.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-17.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-76.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-192.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_159.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_43.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-2.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-58.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-105.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-110.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-189.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-191.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_11.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-105.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-177.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-11.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-98.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_125.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_126.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-108.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-188.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-172.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-12.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-75.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-87.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_52.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-66.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-114.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-151.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_47.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-25.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-85.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_130.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-96.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-93.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_180.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-197.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-137.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-50.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-75.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-2.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-151.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-154.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-22.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-130.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-19.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_185.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-77.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-61.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-117.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-107.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-79.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-115.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_80.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-35.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-130.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-187.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-77.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_189.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_152.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_97.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-45.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-38.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-93.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-158.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_110.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-5.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-143.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_173.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-70.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-67.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-35.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_109.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_59.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_57.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_54.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-125.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_29.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_74.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_85.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_151.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_36.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-134.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-62.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-29.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-168.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-145.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-143.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_81.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-119.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-168.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-104.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-42.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_112.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-100.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-187.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-153.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-69.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-60.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_175.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-77.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-50.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-64.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_102.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-53.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-95.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-78.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-28.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-179.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-53.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_177.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-112.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-143.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-52.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_147.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-65.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_23.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-145.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-81.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-40.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_3.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-28.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-62.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_49.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-130.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-9.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-42.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_172.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_75.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-58.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-31.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-149.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-13.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-193.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-84.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_136.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_144.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_16.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_132.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-132.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-167.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-102.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-20.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-163.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-185.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-20.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_76.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-141.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-132.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-44.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_17.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_160.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-111.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-72.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-70.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_99.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-106.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_155.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_103.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-34.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-173.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-6.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-73.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_150.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-59.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-64.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-190.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-68.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_44.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-173.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-128.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-52.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-176.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-199.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-50.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-135.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_105.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-83.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-159.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-138.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_92.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-91.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-88.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_95.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-133.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-63.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-114.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-57.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_114.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_64.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_166.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-193.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-134.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-120.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-4.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_53.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-186.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-34.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-138.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_182.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-109.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_129.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-75.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-87.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-148.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-157.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-198.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_169.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-39.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-144.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-106.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-150.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-177.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-121.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-92.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_50.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_121.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-99.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-142.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-158.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-174.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-39.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-4.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_116.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-185.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-1.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-178.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-126.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_91.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_37.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-127.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-74.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-137.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_157.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_119.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-137.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-176.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-41.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-94.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-135.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-38.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-110.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-54.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-18.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-148.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_142.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-87.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-53.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-139.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-122.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-123.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-82.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-13.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-108.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_61.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-155.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-178.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-8.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-80.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-155.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-160.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_179.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-7.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-85.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-65.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-63.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-33.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_12.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-40.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_30.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-197.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-123.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_188.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-31.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-74.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-90.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_2.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_178.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-43.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_9.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-196.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-30.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-86.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_193.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_137.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-9.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-19.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-140.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-134.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-149.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_25.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-27.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-14.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-37.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_100.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_167.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_106.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-167.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_24.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-144.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-68.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-67.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_101.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-115.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-135.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_124.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-97.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-189.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-155.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-66.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-123.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-197.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-14.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-15.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-41.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-24.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-30.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-195.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-157.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-124.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-162.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-11.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-37.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_86.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-110.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-126.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-95.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_156.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_72.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-181.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-182.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-172.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-131.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-158.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-187.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-186.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-99.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-38.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_115.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_123.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_67.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-16.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_51.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_158.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-156.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-103.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-113.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-128.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-26.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_82.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-144.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-4.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-192.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-122.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-150.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-161.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_31.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_32.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_84.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-89.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-128.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-48.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-56.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-1.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-61.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-101.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-97.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-196.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-188.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-66.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-29.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-190.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-129.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-51.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_40.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-181.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_66.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-119.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_34.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-32.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-127.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-194.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_65.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-175.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-90.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-194.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-159.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-200.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_48.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-90.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-136.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-173.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-89.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_46.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_88.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-55.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-25.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-109.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-165.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-183.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_42.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-52.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_191.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-177.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-18.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_122.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-86.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-152.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-35.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-161.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-102.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_171.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-146.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-120.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-171.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-92.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-148.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-126.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-124.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-136.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-168.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-84.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_39.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-21.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-23.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-69.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_93.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-97.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-200.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-51.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-12.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-170.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_22.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-184.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-32.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_181.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-96.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-78.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-133.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-117.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_20.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-82.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-89.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_0.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-119.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-61.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-118.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_149.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-101.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_45.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-199.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_113.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-140.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-24.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-116.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-114.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-121.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-33.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-78.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-142.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-60.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-169.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-71.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-156.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_21.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-145.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-76.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_19.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-182.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-10.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-36.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-186.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-18.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-131.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_18.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-132.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-48.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-74.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-43.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-192.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-11.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-84.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-16.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-3.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_161.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-72.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-122.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-167.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-174.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_8.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-71.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-98.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_35.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-54.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_41.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-88.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-183.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-45.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-200.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-163.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-154.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_146.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_133.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-55.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-180.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-17.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-118.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-80.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-164.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-49.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_38.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-180.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-83.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-169.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_117.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-171.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-34.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-5.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-162.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-141.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_87.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-55.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-16.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-142.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-36.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_128.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_33.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-26.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_13.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_164.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-8.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-47.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-191.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-149.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-5.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-2.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_139.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-98.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_4.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-100.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-30.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_98.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-182.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-121.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_127.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-164.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_111.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-116.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-46.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_143.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_194.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_28.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-104.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-85.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-115.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-73.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-156.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-185.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-46.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-91.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-72.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_77.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-125.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-116.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-175.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-111.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-88.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_78.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_168.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-170.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-32.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-57.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-1.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_14.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_73.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_83.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-58.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-14.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_141.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-68.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-59.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-191.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-124.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-91.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-172.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-7.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-3.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_140.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_118.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-139.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-136.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-152.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_58.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-31.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-195.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-196.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-94.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_60.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-26.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-184.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_120.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-141.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_15.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_96.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-153.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-64.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-152.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_186.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_1.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-146.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-129.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-104.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-83.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-118.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-33.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-140.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-15.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-94.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-92.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-166.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-131.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-6.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-21.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_165.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-60.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-13.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-147.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-63.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_26.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_190.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-62.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-19.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_107.jpg have size of (300, 300, 3)
# Image ../images_src/rotate_images_108.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-3.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-43.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-86.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_183.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-199.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-189.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-169.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-17.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-171.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-188.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-151.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-166.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_69.jpg have size of (300, 300, 3)
# Image ../images_src/right_my_photo-138.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-190.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_7.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-147.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-79.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-99.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-105.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-165.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-113.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-147.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-39.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-47.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-112.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_148.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-163.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_94.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-195.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_145.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-162.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-176.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-44.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-40.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-95.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-108.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-160.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_79.jpg have size of (300, 300, 3)
# Image ../images_src/left_my_photo-49.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-180.jpg have size of (480, 640, 3)
# Image ../images_src/straight_my_photo-198.jpg have size of (480, 640, 3)
# Image ../images_src/left_my_photo-12.jpg have size of (480, 640, 3)
# Image ../images_src/right_my_photo-71.jpg have size of (480, 640, 3)
# Image ../images_src/rotate_images_56.jpg have size of (300, 300, 3)
# Image ../images_src/straight_my_photo-175.jpg have size of (480, 640, 3)
# We have 791 images

# %% [markdown]
# As you can see we have images of different sizes. Tuple of 3 numbers correspond to (width, height, channels). All our images are color images and consist of 3 channels RGB: red, green and blue.

# %%
# sample images
img1 = random.randint(0, len(images))
img2 = random.randint(0, len(images))

print(img1, img2)

ia.imshow(images[img1])
ia.imshow(images[img2])
# Out:
# 100 226

# %% [markdown]
# All our images depict red pandas. Images are courtsey of Unsplash.com and their respective owners as described in image file names.
#
# Now let's have a look at one of the XML files.

# %%
# XML file names correspond to the image file names
xml = glob.glob('{}/*.xml'.format(img_src))
# print(xml)
for index, file in enumerate(xml):
    print(file)
# Out:
# ../images_src/left_my_photo-7.xml
# ../images_src/rotate_images_42.xml
# ../images_src/straight_my_photo-161.xml
# ../images_src/right_my_photo-196.xml
# ../images_src/rotate_images_43.xml
# ../images_src/right_my_photo-128.xml
# ../images_src/rotate_images_13.xml
# ../images_src/right_my_photo-10.xml
# ../images_src/right_my_photo-100.xml
# ../images_src/rotate_images_113.xml
# ../images_src/left_my_photo-177.xml
# ../images_src/rotate_images_29.xml
# ../images_src/right_my_photo-49.xml
# ../images_src/left_my_photo-40.xml
# ../images_src/left_my_photo-77.xml
# ../images_src/rotate_images_81.xml
# ../images_src/rotate_images_97.xml
# ../images_src/rotate_images_108.xml
# ../images_src/left_my_photo-49.xml
# ../images_src/rotate_images_18.xml
# ../images_src/straight_my_photo-91.xml
# ../images_src/right_my_photo-146.xml
# ../images_src/left_my_photo-27.xml
# ../images_src/right_my_photo-14.xml
# ../images_src/right_my_photo-138.xml
# ../images_src/left_my_photo-119.xml
# ../images_src/right_my_photo-134.xml
# ../images_src/left_my_photo-48.xml
# ../images_src/right_my_photo-108.xml
# ../images_src/left_my_photo-137.xml
# ../images_src/straight_my_photo-199.xml
# ../images_src/left_my_photo-52.xml
# ../images_src/left_my_photo-196.xml
# ../images_src/right_my_photo-83.xml
# ../images_src/left_my_photo-39.xml
# ../images_src/right_my_photo-104.xml
# ../images_src/right_my_photo-152.xml
# ../images_src/rotate_images_167.xml
# ../images_src/left_my_photo-126.xml
# ../images_src/left_my_photo-66.xml
# ../images_src/straight_my_photo-52.xml
# ../images_src/right_my_photo-177.xml
# ../images_src/straight_my_photo-170.xml
# ../images_src/rotate_images_100.xml
# ../images_src/right_my_photo-75.xml
# ../images_src/left_my_photo-70.xml
# ../images_src/rotate_images_112.xml
# ../images_src/rotate_images_35.xml
# ../images_src/straight_my_photo-95.xml
# ../images_src/left_my_photo-123.xml
# ../images_src/right_my_photo-88.xml
# ../images_src/left_my_photo-114.xml
# ../images_src/right_my_photo-159.xml
# ../images_src/rotate_images_82.xml
# ../images_src/left_my_photo-144.xml
# ../images_src/straight_my_photo-69.xml
# ../images_src/rotate_images_126.xml
# ../images_src/right_my_photo-36.xml
# ../images_src/straight_my_photo-94.xml
# ../images_src/right_my_photo-110.xml
# ../images_src/straight_my_photo-36.xml
# ../images_src/right_my_photo-89.xml
# ../images_src/straight_my_photo-109.xml
# ../images_src/rotate_images_11.xml
# ../images_src/right_my_photo-129.xml
# ../images_src/rotate_images_191.xml
# ../images_src/straight_my_photo-48.xml
# ../images_src/straight_my_photo-189.xml
# ../images_src/right_my_photo-172.xml
# ../images_src/right_my_photo-160.xml
# ../images_src/left_my_photo-71.xml
# ../images_src/rotate_images_5.xml
# ../images_src/rotate_images_45.xml
# ../images_src/rotate_images_168.xml
# ../images_src/right_my_photo-32.xml
# ../images_src/left_my_photo-57.xml
# ../images_src/right_my_photo-40.xml
# ../images_src/left_my_photo-184.xml
# ../images_src/rotate_images_44.xml
# ../images_src/rotate_images_80.xml
# ../images_src/right_my_photo-61.xml
# ../images_src/right_my_photo-93.xml
# ../images_src/straight_my_photo-117.xml
# ../images_src/straight_my_photo-108.xml
# ../images_src/rotate_images_6.xml
# ../images_src/left_my_photo-140.xml
# ../images_src/straight_my_photo-77.xml
# ../images_src/rotate_images_33.xml
# ../images_src/straight_my_photo-137.xml
# ../images_src/rotate_images_139.xml
# ../images_src/left_my_photo-109.xml
# ../images_src/left_my_photo-162.xml
# ../images_src/rotate_images_164.xml
# ../images_src/straight_my_photo-30.xml
# ../images_src/left_my_photo-200.xml
# ../images_src/left_my_photo-179.xml
# ../images_src/rotate_images_23.xml
# ../images_src/right_my_photo-64.xml
# ../images_src/straight_my_photo-182.xml
# ../images_src/right_my_photo-132.xml
# ../images_src/rotate_images_7.xml
# ../images_src/straight_my_photo-27.xml
# ../images_src/right_my_photo-77.xml
# ../images_src/right_my_photo-66.xml
# ../images_src/straight_my_photo-196.xml
# ../images_src/left_my_photo-193.xml
# ../images_src/rotate_images_0.xml
# ../images_src/right_my_photo-197.xml
# ../images_src/straight_my_photo-153.xml
# ../images_src/right_my_photo-127.xml
# ../images_src/right_my_photo-120.xml
# ../images_src/rotate_images_55.xml
# ../images_src/left_my_photo-56.xml
# ../images_src/right_my_photo-168.xml
# ../images_src/straight_my_photo-90.xml
# ../images_src/left_my_photo-185.xml
# ../images_src/right_my_photo-109.xml
# ../images_src/straight_my_photo-14.xml
# ../images_src/straight_my_photo-136.xml
# ../images_src/straight_my_photo-168.xml
# ../images_src/right_my_photo-101.xml
# ../images_src/left_my_photo-88.xml
# ../images_src/straight_my_photo-152.xml
# ../images_src/straight_my_photo-31.xml
# ../images_src/right_my_photo-17.xml
# ../images_src/left_my_photo-128.xml
# ../images_src/right_my_photo-195.xml
# ../images_src/straight_my_photo-92.xml
# ../images_src/right_my_photo-51.xml
# ../images_src/left_my_photo-148.xml
# ../images_src/left_my_photo-6.xml
# ../images_src/straight_my_photo-47.xml
# ../images_src/left_my_photo-171.xml
# ../images_src/straight_my_photo-89.xml
# ../images_src/left_my_photo-61.xml
# ../images_src/right_my_photo-82.xml
# ../images_src/left_my_photo-33.xml
# ../images_src/straight_my_photo-186.xml
# ../images_src/left_my_photo-102.xml
# ../images_src/left_my_photo-182.xml
# ../images_src/straight_my_photo-119.xml
# ../images_src/straight_my_photo-38.xml
# ../images_src/straight_my_photo-195.xml
# ../images_src/left_my_photo-174.xml
# ../images_src/rotate_images_142.xml
# ../images_src/right_my_photo-131.xml
# ../images_src/left_my_photo-65.xml
# ../images_src/straight_my_photo-172.xml
# ../images_src/right_my_photo-20.xml
# ../images_src/left_my_photo-104.xml
# ../images_src/straight_my_photo-72.xml
# ../images_src/right_my_photo-74.xml
# ../images_src/left_my_photo-26.xml
# ../images_src/straight_my_photo-56.xml
# ../images_src/left_my_photo-139.xml
# ../images_src/rotate_images_66.xml
# ../images_src/right_my_photo-4.xml
# ../images_src/straight_my_photo-123.xml
# ../images_src/rotate_images_70.xml
# ../images_src/right_my_photo-170.xml
# ../images_src/rotate_images_185.xml
# ../images_src/left_my_photo-89.xml
# ../images_src/right_my_photo-142.xml
# ../images_src/left_my_photo-12.xml
# ../images_src/straight_my_photo-146.xml
# ../images_src/rotate_images_187.xml
# ../images_src/right_my_photo-121.xml
# ../images_src/rotate_images_36.xml
# ../images_src/left_my_photo-20.xml
# ../images_src/left_my_photo-60.xml
# ../images_src/straight_my_photo-55.xml
# ../images_src/rotate_images_134.xml
# ../images_src/straight_my_photo-88.xml
# ../images_src/left_my_photo-127.xml
# ../images_src/rotate_images_136.xml
# ../images_src/right_my_photo-164.xml
# ../images_src/rotate_images_17.xml
# ../images_src/rotate_images_147.xml
# ../images_src/left_my_photo-46.xml
# ../images_src/straight_my_photo-166.xml
# ../images_src/left_my_photo-53.xml
# ../images_src/right_my_photo-12.xml
# ../images_src/right_my_photo-189.xml
# ../images_src/left_my_photo-15.xml
# ../images_src/left_my_photo-17.xml
# ../images_src/straight_my_photo-71.xml
# ../images_src/rotate_images_89.xml
# ../images_src/right_my_photo-183.xml
# ../images_src/straight_my_photo-54.xml
# ../images_src/rotate_images_137.xml
# ../images_src/straight_my_photo-39.xml
# ../images_src/straight_my_photo-44.xml
# ../images_src/right_my_photo-116.xml
# ../images_src/right_my_photo-22.xml
# ../images_src/left_my_photo-181.xml
# ../images_src/left_my_photo-68.xml
# ../images_src/rotate_images_74.xml
# ../images_src/left_my_photo-163.xml
# ../images_src/left_my_photo-191.xml
# ../images_src/left_my_photo-197.xml
# ../images_src/left_my_photo-32.xml
# ../images_src/right_my_photo-96.xml
# ../images_src/straight_my_photo-57.xml
# ../images_src/right_my_photo-114.xml
# ../images_src/rotate_images_96.xml
# ../images_src/rotate_images_166.xml
# ../images_src/left_my_photo-90.xml
# ../images_src/left_my_photo-152.xml
# ../images_src/right_my_photo-55.xml
# ../images_src/straight_my_photo-15.xml
# ../images_src/rotate_images_57.xml
# ../images_src/rotate_images_48.xml
# ../images_src/straight_my_photo-192.xml
# ../images_src/straight_my_photo-148.xml
# ../images_src/right_my_photo-144.xml
# ../images_src/straight_my_photo-59.xml
# ../images_src/rotate_images_91.xml
# ../images_src/left_my_photo-121.xml
# ../images_src/rotate_images_46.xml
# ../images_src/straight_my_photo-20.xml
# ../images_src/right_my_photo-95.xml
# ../images_src/rotate_images_84.xml
# ../images_src/left_my_photo-170.xml
# ../images_src/rotate_images_135.xml
# ../images_src/straight_my_photo-83.xml
# ../images_src/right_my_photo-63.xml
# ../images_src/right_my_photo-111.xml
# ../images_src/right_my_photo-126.xml
# ../images_src/straight_my_photo-29.xml
# ../images_src/rotate_images_121.xml
# ../images_src/straight_my_photo-187.xml
# ../images_src/right_my_photo-176.xml
# ../images_src/right_my_photo-76.xml
# ../images_src/right_my_photo-11.xml
# ../images_src/rotate_images_179.xml
# ../images_src/left_my_photo-9.xml
# ../images_src/right_my_photo-124.xml
# ../images_src/straight_my_photo-167.xml
# ../images_src/rotate_images_158.xml
# ../images_src/right_my_photo-97.xml
# ../images_src/rotate_images_16.xml
# ../images_src/left_my_photo-45.xml
# ../images_src/rotate_images_145.xml
# ../images_src/left_my_photo-178.xml
# ../images_src/rotate_images_56.xml
# ../images_src/rotate_images_79.xml
# ../images_src/straight_my_photo-13.xml
# ../images_src/right_my_photo-26.xml
# ../images_src/rotate_images_173.xml
# ../images_src/rotate_images_101.xml
# ../images_src/left_my_photo-151.xml
# ../images_src/rotate_images_193.xml
# ../images_src/rotate_images_153.xml
# ../images_src/left_my_photo-194.xml
# ../images_src/left_my_photo-142.xml
# ../images_src/right_my_photo-92.xml
# ../images_src/straight_my_photo-122.xml
# ../images_src/left_my_photo-100.xml
# ../images_src/left_my_photo-74.xml
# ../images_src/right_my_photo-130.xml
# ../images_src/right_my_photo-3.xml
# ../images_src/right_my_photo-117.xml
# ../images_src/straight_my_photo-151.xml
# ../images_src/right_my_photo-15.xml
# ../images_src/straight_my_photo-101.xml
# ../images_src/right_my_photo-29.xml
# ../images_src/left_my_photo-47.xml
# ../images_src/right_my_photo-52.xml
# ../images_src/straight_my_photo-76.xml
# ../images_src/straight_my_photo-9.xml
# ../images_src/straight_my_photo-43.xml
# ../images_src/right_my_photo-194.xml
# ../images_src/right_my_photo-33.xml
# ../images_src/rotate_images_12.xml
# ../images_src/right_my_photo-150.xml
# ../images_src/left_my_photo-131.xml
# ../images_src/left_my_photo-92.xml
# ../images_src/straight_my_photo-98.xml
# ../images_src/rotate_images_93.xml
# ../images_src/right_my_photo-38.xml
# ../images_src/left_my_photo-24.xml
# ../images_src/rotate_images_123.xml
# ../images_src/right_my_photo-78.xml
# ../images_src/left_my_photo-156.xml
# ../images_src/left_my_photo-35.xml
# ../images_src/left_my_photo-54.xml
# ../images_src/straight_my_photo-41.xml
# ../images_src/straight_my_photo-173.xml
# ../images_src/rotate_images_148.xml
# ../images_src/straight_my_photo-93.xml
# ../images_src/straight_my_photo-132.xml
# ../images_src/rotate_images_76.xml
# ../images_src/straight_my_photo-33.xml
# ../images_src/rotate_images_170.xml
# ../images_src/straight_my_photo-80.xml
# ../images_src/right_my_photo-147.xml
# ../images_src/right_my_photo-21.xml
# ../images_src/rotate_images_15.xml
# ../images_src/left_my_photo-37.xml
# ../images_src/straight_my_photo-58.xml
# ../images_src/straight_my_photo-121.xml
# ../images_src/left_my_photo-98.xml
# ../images_src/right_my_photo-154.xml
# ../images_src/right_my_photo-191.xml
# ../images_src/straight_my_photo-171.xml
# ../images_src/straight_my_photo-185.xml
# ../images_src/rotate_images_171.xml
# ../images_src/left_my_photo-31.xml
# ../images_src/rotate_images_50.xml
# ../images_src/straight_my_photo-115.xml
# ../images_src/right_my_photo-105.xml
# ../images_src/right_my_photo-169.xml
# ../images_src/straight_my_photo-96.xml
# ../images_src/rotate_images_71.xml
# ../images_src/right_my_photo-85.xml
# ../images_src/right_my_photo-87.xml
# ../images_src/straight_my_photo-73.xml
# ../images_src/rotate_images_152.xml
# ../images_src/left_my_photo-146.xml
# ../images_src/straight_my_photo-156.xml
# ../images_src/left_my_photo-175.xml
# ../images_src/straight_my_photo-141.xml
# ../images_src/left_my_photo-141.xml
# ../images_src/straight_my_photo-188.xml
# ../images_src/right_my_photo-70.xml
# ../images_src/rotate_images_138.xml
# ../images_src/rotate_images_64.xml
# ../images_src/right_my_photo-112.xml
# ../images_src/rotate_images_102.xml
# ../images_src/rotate_images_88.xml
# ../images_src/left_my_photo-106.xml
# ../images_src/left_my_photo-172.xml
# ../images_src/right_my_photo-35.xml
# ../images_src/straight_my_photo-134.xml
# ../images_src/rotate_images_60.xml
# ../images_src/left_my_photo-189.xml
# ../images_src/left_my_photo-135.xml
# ../images_src/straight_my_photo-3.xml
# ../images_src/straight_my_photo-139.xml
# ../images_src/rotate_images_41.xml
# ../images_src/right_my_photo-60.xml
# ../images_src/left_my_photo-11.xml
# ../images_src/right_my_photo-6.xml
# ../images_src/left_my_photo-76.xml
# ../images_src/rotate_images_129.xml
# ../images_src/rotate_images_51.xml
# ../images_src/straight_my_photo-175.xml
# ../images_src/right_my_photo-192.xml
# ../images_src/left_my_photo-87.xml
# ../images_src/rotate_images_20.xml
# ../images_src/straight_my_photo-63.xml
# ../images_src/left_my_photo-18.xml
# ../images_src/straight_my_photo-130.xml
# ../images_src/straight_my_photo-110.xml
# ../images_src/left_my_photo-166.xml
# ../images_src/straight_my_photo-2.xml
# ../images_src/straight_my_photo-6.xml
# ../images_src/left_my_photo-115.xml
# ../images_src/straight_my_photo-62.xml
# ../images_src/left_my_photo-190.xml
# ../images_src/right_my_photo-2.xml
# ../images_src/right_my_photo-41.xml
# ../images_src/right_my_photo-45.xml
# ../images_src/right_my_photo-187.xml
# ../images_src/left_my_photo-59.xml
# ../images_src/right_my_photo-62.xml
# ../images_src/right_my_photo-186.xml
# ../images_src/straight_my_photo-7.xml
# ../images_src/right_my_photo-125.xml
# ../images_src/straight_my_photo-5.xml
# ../images_src/right_my_photo-67.xml
# ../images_src/left_my_photo-29.xml
# ../images_src/rotate_images_62.xml
# ../images_src/left_my_photo-23.xml
# ../images_src/right_my_photo-68.xml
# ../images_src/left_my_photo-67.xml
# ../images_src/rotate_images_128.xml
# ../images_src/rotate_images_95.xml
# ../images_src/rotate_images_83.xml
# ../images_src/left_my_photo-96.xml
# ../images_src/rotate_images_169.xml
# ../images_src/straight_my_photo-1.xml
# ../images_src/right_my_photo-102.xml
# ../images_src/straight_my_photo-131.xml
# ../images_src/right_my_photo-188.xml
# ../images_src/straight_my_photo-164.xml
# ../images_src/right_my_photo-200.xml
# ../images_src/right_my_photo-162.xml
# ../images_src/left_my_photo-95.xml
# ../images_src/right_my_photo-107.xml
# ../images_src/rotate_images_155.xml
# ../images_src/left_my_photo-78.xml
# ../images_src/rotate_images_140.xml
# ../images_src/left_my_photo-113.xml
# ../images_src/left_my_photo-86.xml
# ../images_src/right_my_photo-47.xml
# ../images_src/straight_my_photo-162.xml
# ../images_src/rotate_images_65.xml
# ../images_src/straight_my_photo-46.xml
# ../images_src/right_my_photo-103.xml
# ../images_src/right_my_photo-71.xml
# ../images_src/left_my_photo-195.xml
# ../images_src/rotate_images_117.xml
# ../images_src/right_my_photo-7.xml
# ../images_src/straight_my_photo-191.xml
# ../images_src/straight_my_photo-165.xml
# ../images_src/rotate_images_156.xml
# ../images_src/rotate_images_116.xml
# ../images_src/left_my_photo-149.xml
# ../images_src/left_my_photo-169.xml
# ../images_src/straight_my_photo-103.xml
# ../images_src/left_my_photo-154.xml
# ../images_src/rotate_images_172.xml
# ../images_src/right_my_photo-139.xml
# ../images_src/left_my_photo-80.xml
# ../images_src/right_my_photo-158.xml
# ../images_src/rotate_images_26.xml
# ../images_src/left_my_photo-136.xml
# ../images_src/right_my_photo-9.xml
# ../images_src/straight_my_photo-181.xml
# ../images_src/rotate_images_78.xml
# ../images_src/rotate_images_130.xml
# ../images_src/straight_my_photo-28.xml
# ../images_src/right_my_photo-39.xml
# ../images_src/straight_my_photo-183.xml
# ../images_src/right_my_photo-69.xml
# ../images_src/straight_my_photo-107.xml
# ../images_src/right_my_photo-106.xml
# ../images_src/straight_my_photo-177.xml
# ../images_src/left_my_photo-153.xml
# ../images_src/left_my_photo-44.xml
# ../images_src/straight_my_photo-42.xml
# ../images_src/rotate_images_47.xml
# ../images_src/rotate_images_143.xml
# ../images_src/left_my_photo-101.xml
# ../images_src/right_my_photo-99.xml
# ../images_src/right_my_photo-199.xml
# ../images_src/right_my_photo-73.xml
# ../images_src/rotate_images_181.xml
# ../images_src/right_my_photo-86.xml
# ../images_src/right_my_photo-28.xml
# ../images_src/right_my_photo-174.xml
# ../images_src/rotate_images_19.xml
# ../images_src/left_my_photo-158.xml
# ../images_src/left_my_photo-132.xml
# ../images_src/left_my_photo-103.xml
# ../images_src/straight_my_photo-86.xml
# ../images_src/right_my_photo-141.xml
# ../images_src/right_my_photo-151.xml
# ../images_src/left_my_photo-145.xml
# ../images_src/left_my_photo-10.xml
# ../images_src/straight_my_photo-45.xml
# ../images_src/left_my_photo-116.xml
# ../images_src/straight_my_photo-53.xml
# ../images_src/left_my_photo-187.xml
# ../images_src/rotate_images_94.xml
# ../images_src/rotate_images_32.xml
# ../images_src/straight_my_photo-113.xml
# ../images_src/straight_my_photo-12.xml
# ../images_src/rotate_images_122.xml
# ../images_src/left_my_photo-112.xml
# ../images_src/rotate_images_175.xml
# ../images_src/rotate_images_1.xml
# ../images_src/left_my_photo-13.xml
# ../images_src/left_my_photo-30.xml
# ../images_src/rotate_images_27.xml
# ../images_src/straight_my_photo-99.xml
# ../images_src/rotate_images_157.xml
# ../images_src/left_my_photo-147.xml
# ../images_src/left_my_photo-51.xml
# ../images_src/left_my_photo-55.xml
# ../images_src/straight_my_photo-174.xml
# ../images_src/right_my_photo-161.xml
# ../images_src/rotate_images_154.xml
# ../images_src/straight_my_photo-125.xml
# ../images_src/rotate_images_98.xml
# ../images_src/left_my_photo-50.xml
# ../images_src/rotate_images_119.xml
# ../images_src/left_my_photo-107.xml
# ../images_src/rotate_images_86.xml
# ../images_src/left_my_photo-75.xml
# ../images_src/rotate_images_105.xml
# ../images_src/left_my_photo-2.xml
# ../images_src/rotate_images_49.xml
# ../images_src/right_my_photo-80.xml
# ../images_src/right_my_photo-56.xml
# ../images_src/rotate_images_183.xml
# ../images_src/rotate_images_192.xml
# ../images_src/straight_my_photo-184.xml
# ../images_src/left_my_photo-167.xml
# ../images_src/left_my_photo-25.xml
# ../images_src/right_my_photo-59.xml
# ../images_src/rotate_images_92.xml
# ../images_src/left_my_photo-72.xml
# ../images_src/right_my_photo-13.xml
# ../images_src/straight_my_photo-4.xml
# ../images_src/left_my_photo-83.xml
# ../images_src/left_my_photo-120.xml
# ../images_src/left_my_photo-5.xml
# ../images_src/rotate_images_58.xml
# ../images_src/straight_my_photo-169.xml
# ../images_src/left_my_photo-19.xml
# ../images_src/rotate_images_24.xml
# ../images_src/rotate_images_125.xml
# ../images_src/straight_my_photo-142.xml
# ../images_src/right_my_photo-34.xml
# ../images_src/straight_my_photo-120.xml
# ../images_src/right_my_photo-140.xml
# ../images_src/straight_my_photo-61.xml
# ../images_src/rotate_images_61.xml
# ../images_src/straight_my_photo-67.xml
# ../images_src/rotate_images_28.xml
# ../images_src/rotate_images_146.xml
# ../images_src/rotate_images_39.xml
# ../images_src/left_my_photo-84.xml
# ../images_src/right_my_photo-173.xml
# ../images_src/straight_my_photo-100.xml
# ../images_src/rotate_images_73.xml
# ../images_src/straight_my_photo-180.xml
# ../images_src/right_my_photo-16.xml
# ../images_src/rotate_images_77.xml
# ../images_src/straight_my_photo-163.xml
# ../images_src/straight_my_photo-179.xml
# ../images_src/straight_my_photo-81.xml
# ../images_src/rotate_images_30.xml
# ../images_src/rotate_images_3.xml
# ../images_src/straight_my_photo-66.xml
# ../images_src/straight_my_photo-21.xml
# ../images_src/left_my_photo-62.xml
# ../images_src/right_my_photo-135.xml
# ../images_src/left_my_photo-188.xml
# ../images_src/rotate_images_31.xml
# ../images_src/left_my_photo-186.xml
# ../images_src/right_my_photo-1.xml
# ../images_src/straight_my_photo-190.xml
# ../images_src/straight_my_photo-200.xml
# ../images_src/right_my_photo-123.xml
# ../images_src/straight_my_photo-37.xml
# ../images_src/straight_my_photo-157.xml
# ../images_src/left_my_photo-8.xml
# ../images_src/right_my_photo-58.xml
# ../images_src/rotate_images_37.xml
# ../images_src/left_my_photo-93.xml
# ../images_src/straight_my_photo-143.xml
# ../images_src/left_my_photo-110.xml
# ../images_src/right_my_photo-149.xml
# ../images_src/right_my_photo-184.xml
# ../images_src/right_my_photo-53.xml
# ../images_src/straight_my_photo-135.xml
# ../images_src/left_my_photo-73.xml
# ../images_src/left_my_photo-192.xml
# ../images_src/left_my_photo-117.xml
# ../images_src/rotate_images_177.xml
# ../images_src/straight_my_photo-16.xml
# ../images_src/left_my_photo-21.xml
# ../images_src/left_my_photo-36.xml
# ../images_src/left_my_photo-41.xml
# ../images_src/right_my_photo-31.xml
# ../images_src/straight_my_photo-160.xml
# ../images_src/rotate_images_53.xml
# ../images_src/right_my_photo-133.xml
# ../images_src/rotate_images_159.xml
# ../images_src/rotate_images_106.xml
# ../images_src/right_my_photo-46.xml
# ../images_src/rotate_images_68.xml
# ../images_src/left_my_photo-134.xml
# ../images_src/left_my_photo-133.xml
# ../images_src/left_my_photo-99.xml
# ../images_src/right_my_photo-167.xml
# ../images_src/right_my_photo-115.xml
# ../images_src/left_my_photo-85.xml
# ../images_src/straight_my_photo-65.xml
# ../images_src/rotate_images_188.xml
# ../images_src/left_my_photo-168.xml
# ../images_src/left_my_photo-125.xml
# ../images_src/rotate_images_133.xml
# ../images_src/straight_my_photo-84.xml
# ../images_src/rotate_images_178.xml
# ../images_src/straight_my_photo-129.xml
# ../images_src/right_my_photo-27.xml
# ../images_src/straight_my_photo-178.xml
# ../images_src/rotate_images_132.xml
# ../images_src/right_my_photo-143.xml
# ../images_src/straight_my_photo-144.xml
# ../images_src/left_my_photo-69.xml
# ../images_src/left_my_photo-176.xml
# ../images_src/rotate_images_162.xml
# ../images_src/left_my_photo-91.xml
# ../images_src/rotate_images_22.xml
# ../images_src/right_my_photo-91.xml
# ../images_src/rotate_images_176.xml
# ../images_src/straight_my_photo-26.xml
# ../images_src/right_my_photo-43.xml
# ../images_src/straight_my_photo-159.xml
# ../images_src/straight_my_photo-49.xml
# ../images_src/left_my_photo-97.xml
# ../images_src/right_my_photo-44.xml
# ../images_src/left_my_photo-180.xml
# ../images_src/right_my_photo-84.xml
# ../images_src/rotate_images_161.xml
# ../images_src/right_my_photo-166.xml
# ../images_src/right_my_photo-155.xml
# ../images_src/rotate_images_9.xml
# ../images_src/left_my_photo-108.xml
# ../images_src/rotate_images_127.xml
# ../images_src/right_my_photo-25.xml
# ../images_src/straight_my_photo-64.xml
# ../images_src/rotate_images_111.xml
# ../images_src/rotate_images_85.xml
# ../images_src/right_my_photo-165.xml
# ../images_src/right_my_photo-163.xml
# ../images_src/straight_my_photo-50.xml
# ../images_src/straight_my_photo-124.xml
# ../images_src/right_my_photo-98.xml
# ../images_src/rotate_images_163.xml
# ../images_src/rotate_images_189.xml
# ../images_src/left_my_photo-111.xml
# ../images_src/straight_my_photo-133.xml
# ../images_src/left_my_photo-138.xml
# ../images_src/rotate_images_144.xml
# ../images_src/rotate_images_131.xml
# ../images_src/right_my_photo-137.xml
# ../images_src/rotate_images_124.xml
# ../images_src/straight_my_photo-158.xml
# ../images_src/straight_my_photo-82.xml
# ../images_src/right_my_photo-8.xml
# ../images_src/straight_my_photo-105.xml
# ../images_src/left_my_photo-82.xml
# ../images_src/right_my_photo-50.xml
# ../images_src/right_my_photo-94.xml
# ../images_src/rotate_images_10.xml
# ../images_src/straight_my_photo-155.xml
# ../images_src/left_my_photo-129.xml
# ../images_src/right_my_photo-5.xml
# ../images_src/right_my_photo-72.xml
# ../images_src/rotate_images_38.xml
# ../images_src/right_my_photo-185.xml
# ../images_src/straight_my_photo-8.xml
# ../images_src/straight_my_photo-149.xml
# ../images_src/straight_my_photo-106.xml
# ../images_src/left_my_photo-164.xml
# ../images_src/rotate_images_190.xml
# ../images_src/straight_my_photo-19.xml
# ../images_src/straight_my_photo-147.xml
# ../images_src/right_my_photo-79.xml
# ../images_src/left_my_photo-38.xml
# ../images_src/rotate_images_149.xml
# ../images_src/left_my_photo-63.xml
# ../images_src/straight_my_photo-118.xml
# ../images_src/rotate_images_110.xml
# ../images_src/straight_my_photo-102.xml
# ../images_src/left_my_photo-155.xml
# ../images_src/straight_my_photo-11.xml
# ../images_src/straight_my_photo-154.xml
# ../images_src/rotate_images_194.xml
# ../images_src/rotate_images_67.xml
# ../images_src/rotate_images_21.xml
# ../images_src/right_my_photo-175.xml
# ../images_src/straight_my_photo-34.xml
# ../images_src/left_my_photo-159.xml
# ../images_src/right_my_photo-178.xml
# ../images_src/right_my_photo-153.xml
# ../images_src/rotate_images_114.xml
# ../images_src/rotate_images_174.xml
# ../images_src/right_my_photo-48.xml
# ../images_src/rotate_images_2.xml
# ../images_src/right_my_photo-179.xml
# ../images_src/straight_my_photo-17.xml
# ../images_src/straight_my_photo-79.xml
# ../images_src/right_my_photo-23.xml
# ../images_src/right_my_photo-193.xml
# ../images_src/left_my_photo-1.xml
# ../images_src/right_my_photo-180.xml
# ../images_src/straight_my_photo-51.xml
# ../images_src/straight_my_photo-111.xml
# ../images_src/rotate_images_54.xml
# ../images_src/rotate_images_104.xml
# ../images_src/left_my_photo-173.xml
# ../images_src/right_my_photo-182.xml
# ../images_src/left_my_photo-3.xml
# ../images_src/rotate_images_14.xml
# ../images_src/rotate_images_182.xml
# ../images_src/left_my_photo-165.xml
# ../images_src/right_my_photo-18.xml
# ../images_src/left_my_photo-130.xml
# ../images_src/straight_my_photo-18.xml
# ../images_src/left_my_photo-150.xml
# ../images_src/straight_my_photo-75.xml
# ../images_src/rotate_images_150.xml
# ../images_src/rotate_images_118.xml
# ../images_src/rotate_images_180.xml
# ../images_src/rotate_images_63.xml
# ../images_src/straight_my_photo-70.xml
# ../images_src/right_my_photo-118.xml
# ../images_src/rotate_images_115.xml
# ../images_src/left_my_photo-16.xml
# ../images_src/left_my_photo-160.xml
# ../images_src/left_my_photo-34.xml
# ../images_src/straight_my_photo-35.xml
# ../images_src/right_my_photo-119.xml
# ../images_src/straight_my_photo-150.xml
# ../images_src/rotate_images_59.xml
# ../images_src/rotate_images_160.xml
# ../images_src/rotate_images_72.xml
# ../images_src/straight_my_photo-140.xml
# ../images_src/straight_my_photo-127.xml
# ../images_src/left_my_photo-79.xml
# ../images_src/left_my_photo-199.xml
# ../images_src/rotate_images_87.xml
# ../images_src/rotate_images_25.xml
# ../images_src/left_my_photo-58.xml
# ../images_src/left_my_photo-157.xml
# ../images_src/right_my_photo-198.xml
# ../images_src/rotate_images_8.xml
# ../images_src/rotate_images_141.xml
# ../images_src/left_my_photo-122.xml
# ../images_src/rotate_images_107.xml
# ../images_src/right_my_photo-30.xml
# ../images_src/rotate_images_186.xml
# ../images_src/rotate_images_109.xml
# ../images_src/right_my_photo-24.xml
# ../images_src/right_my_photo-113.xml
# ../images_src/right_my_photo-136.xml
# ../images_src/straight_my_photo-145.xml
# ../images_src/right_my_photo-156.xml
# ../images_src/left_my_photo-198.xml
# ../images_src/left_my_photo-105.xml
# ../images_src/left_my_photo-28.xml
# ../images_src/right_my_photo-57.xml
# ../images_src/straight_my_photo-40.xml
# ../images_src/left_my_photo-161.xml
# ../images_src/right_my_photo-19.xml
# ../images_src/straight_my_photo-176.xml
# ../images_src/straight_my_photo-128.xml
# ../images_src/rotate_images_103.xml
# ../images_src/straight_my_photo-197.xml
# ../images_src/straight_my_photo-10.xml
# ../images_src/rotate_images_69.xml
# ../images_src/straight_my_photo-138.xml
# ../images_src/right_my_photo-42.xml
# ../images_src/rotate_images_120.xml
# ../images_src/right_my_photo-81.xml
# ../images_src/straight_my_photo-78.xml
# ../images_src/right_my_photo-157.xml
# ../images_src/rotate_images_99.xml
# ../images_src/left_my_photo-81.xml
# ../images_src/right_my_photo-122.xml
# ../images_src/right_my_photo-54.xml
# ../images_src/straight_my_photo-194.xml
# ../images_src/right_my_photo-145.xml
# ../images_src/left_my_photo-14.xml
# ../images_src/straight_my_photo-97.xml
# ../images_src/left_my_photo-43.xml
# ../images_src/straight_my_photo-114.xml
# ../images_src/straight_my_photo-74.xml
# ../images_src/left_my_photo-22.xml
# ../images_src/rotate_images_165.xml
# ../images_src/rotate_images_75.xml
# ../images_src/left_my_photo-143.xml
# ../images_src/right_my_photo-181.xml
# ../images_src/straight_my_photo-126.xml
# ../images_src/straight_my_photo-85.xml
# ../images_src/right_my_photo-190.xml
# ../images_src/straight_my_photo-68.xml
# ../images_src/left_my_photo-124.xml
# ../images_src/straight_my_photo-198.xml
# ../images_src/straight_my_photo-112.xml
# ../images_src/left_my_photo-94.xml
# ../images_src/straight_my_photo-116.xml
# ../images_src/rotate_images_184.xml
# ../images_src/left_my_photo-4.xml
# ../images_src/rotate_images_4.xml
# ../images_src/right_my_photo-90.xml
# ../images_src/straight_my_photo-193.xml
# ../images_src/rotate_images_34.xml
# ../images_src/rotate_images_40.xml
# ../images_src/right_my_photo-171.xml
# ../images_src/rotate_images_151.xml
# ../images_src/straight_my_photo-32.xml
# ../images_src/straight_my_photo-104.xml
# ../images_src/rotate_images_52.xml
# ../images_src/rotate_images_90.xml
# ../images_src/right_my_photo-65.xml
# ../images_src/right_my_photo-148.xml
# ../images_src/left_my_photo-183.xml
# ../images_src/straight_my_photo-60.xml
# ../images_src/left_my_photo-118.xml
# ../images_src/right_my_photo-37.xml
# ../images_src/left_my_photo-42.xml
# ../images_src/left_my_photo-64.xml
# ../images_src/straight_my_photo-87.xml

# %%
# have a look how one of the XML annotation file looks like
# notice how it has 2 bounding boxes with red pandas
xml_idx = random.randint(0, len(xml))
temp_label = "{}/sample_lbl.txt".format(img_src)
shutil.copy(xml[xml_idx], temp_label)
annotation_text = open(temp_label, "r")
print(annotation_text.read())
annotation_text.close()
# Out:
# <?xml version="1.0"?>
# <annotation>
# <folder>data</folder>
# <filename>rotate_images_187.jpg</filename>
# <path/>
# <source>
# <database>Unknown</database>
# </source>
# <size>
# <width>300</width>
# <height>300</height>
# <depth>3</depth>
# </size>
# <segmented>0</segmented>
# <object>
# <name>left</name>
# <pose>Unspecified</pose>
# <truncated>0</truncated>
# <occluded>0</occluded>
# <difficult>0</difficult>
# <bndbox>
# <xmin>73</xmin>
# <ymin>92</ymin>
# <xmax>183</xmax>
# <ymax>155</ymax>
# </bndbox>
# </object>
# </annotation>

# %% [markdown]
# ## 1. Convert all XML files into one CSV file that we can feed into TensorFlow Object Detection API
#
# To convert all separate PASCAL VOC format XML files into one CSV file we will use the [xml_to_csv.py](https://github.com/datitran/raccoon_dataset/blob/master/xml_to_csv.py) code developed by Dan Tran.

# %%
# Function that will extract column data for our CSV file
def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[5][0].text), # [4] if using tzutalin for labeling the images
                     int(member[5][1].text), # [5] if using ybat for labeling the images
                     int(member[5][2].text),
                     int(member[5][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df

# %%
# apply xml_to_csv() function to convert all XML files in images/ folder into labels.csv
labels_df = xml_to_csv('{}/'.format(img_src))
labels_df.to_csv((lbl_src), index=None)
print('Successfully converted xml to csv.')
# Out:
# Successfully converted xml to csv.

# %%
# in previuos cell we also put all annotation in labels_df
# let's see what's inside
# each bounding box has a separate row
# 2 pictures have two red pandas in it
labels_df
# Out:
#                       filename  width  height     class  xmin  ymin  xmax  \
# 0          left_my_photo-7.jpg    640     480      left   257   166   445
# 1         rotate_images_42.jpg    300     300     right   110    80   217
# 2    straight_my_photo-161.jpg    640     480  straight   281   190   453
# 3       right_my_photo-196.jpg    640     480     right    89    69   274
# 4         rotate_images_43.jpg    300     300     right    80    53   192
# 5       right_my_photo-128.jpg    640     480     right   295    95   453
# 6         rotate_images_13.jpg    300     300      left   105   113   231
# 7        right_my_photo-10.jpg    640     480     right   247   128   417
# 8       right_my_photo-100.jpg    640     480     right   379   172   550
# 9        rotate_images_113.jpg    300     300  straight    65    97   181
# 10       left_my_photo-177.jpg    640     480      left   265   294   436
# 11        rotate_images_29.jpg    300     300      left   126   116   195
# 12       right_my_photo-49.jpg    640     480     right   250    66   411
# 13        left_my_photo-40.jpg    640     480      left   390   104   549
# 14        left_my_photo-77.jpg    640     480      left   310    68   453
# 15        rotate_images_81.jpg    300     300  straight    96   129   187
# 16        rotate_images_97.jpg    300     300  straight    99   130   208
# 17       rotate_images_108.jpg    300     300  straight    56    68   210
# 18        left_my_photo-49.jpg    640     480      left   374   100   526
# 19        rotate_images_18.jpg    300     300      left    85   112   183
# 20    straight_my_photo-91.jpg    640     480  straight   276   206   450
# 21      right_my_photo-146.jpg    640     480     right   399    83   567
# 22        left_my_photo-27.jpg    640     480      left   277    49   433
# 23       right_my_photo-14.jpg    640     480     right    74    48   228
# 24      right_my_photo-138.jpg    640     480     right   244   275   414
# 25       left_my_photo-119.jpg    640     480      left   261   101   434
# 26      right_my_photo-134.jpg    640     480     right   231   171   387
# 27        left_my_photo-48.jpg    640     480      left   345     4   479
# 28      right_my_photo-108.jpg    640     480     right   251   219   423
# 29       left_my_photo-137.jpg    640     480      left   338    84   510
# ..                         ...    ...     ...       ...   ...   ...   ...
# 761   straight_my_photo-85.jpg    640     480  straight   197   286   386
# 762     right_my_photo-190.jpg    640     480     right   265   127   420
# 763   straight_my_photo-68.jpg    640     480  straight   372    14   521
# 764      left_my_photo-124.jpg    640     480      left   214     0   344
# 765  straight_my_photo-198.jpg    640     480  straight   288   120   449
# 766  straight_my_photo-112.jpg    640     480  straight   328    57   477
# 767       left_my_photo-94.jpg    640     480      left   367   110   539
# 768  straight_my_photo-116.jpg    640     480  straight   301    95   460
# 769      rotate_images_184.jpg    300     300      left    87   105   180
# 770        left_my_photo-4.jpg    640     480      left   296    66   455
# 771        rotate_images_4.jpg    300     300      left    89   121   193
# 772      right_my_photo-90.jpg    640     480     right   255    26   387
# 773  straight_my_photo-193.jpg    640     480  straight   232   267   398
# 774       rotate_images_34.jpg    300     300     right    67   112   169
# 775       rotate_images_40.jpg    300     300     right   118    97   220
# 776     right_my_photo-171.jpg    640     480     right   152   130   313
# 777      rotate_images_151.jpg    300     300     right    87    74   200
# 778   straight_my_photo-32.jpg    640     480  straight   283   184   437
# 779  straight_my_photo-104.jpg    640     480  straight   270    74   408
# 780       rotate_images_52.jpg    300     300     right    94   161   203
# 781       rotate_images_90.jpg    300     300  straight    47    93   144
# 782      right_my_photo-65.jpg    640     480     right   390    74   579
# 783     right_my_photo-148.jpg    640     480     right   280    92   423
# 784      left_my_photo-183.jpg    640     480      left   213   178   383
# 785   straight_my_photo-60.jpg    640     480  straight   496    33   635
# 786      left_my_photo-118.jpg    640     480      left   321    83   469
# 787      right_my_photo-37.jpg    640     480     right   259    38   394
# 788       left_my_photo-42.jpg    640     480      left   283   264   454
# 789       left_my_photo-64.jpg    640     480      left   307    50   450
# 790   straight_my_photo-87.jpg    640     480  straight   327   158   506
#
#      ymax
# 0     336
# 1     140
# 2     344
# 3     218
# 4     109
# 5     223
# 6     182
# 7     277
# 8     317
# 9     165
# 10    456
# 11    153
# 12    197
# 13    242
# 14    184
# 15    181
# 16    191
# 17    156
# 18    218
# 19    163
# 20    379
# 21    220
# 22    173
# 23    164
# 24    435
# 25    244
# 26    308
# 27    101
# 28    369
# 29    233
# ..    ...
# 761   451
# 762   254
# 763   136
# 764    90
# 765   261
# 766   179
# 767   258
# 768   220
# 769   152
# 770   191
# 771   178
# 772   131
# 773   419
# 774   167
# 775   151
# 776   252
# 777   131
# 778   333
# 779   191
# 780   222
# 781   145
# 782   227
# 783   210
# 784   329
# 785   152
# 786   212
# 787   144
# 788   420
# 789   166
# 790   319
#
# [791 rows x 8 columns]

# %% [markdown]
# ## 2. Resize all images together with the corresponding object bounding boxes
#
# TensorFlow Object Detection API can be fed by images of different sizes. But your GPU might not be able to handle big pictures. Let's say we want to resize all the picture so the width and height should be 600px or less.
#
# To get familiar with basics of image and multiple bounding boxes augmentation refer to this [tutorial](https://nbviewer.jupyter.org/github/aleju/imgaug-doc/blob/master/notebooks/B02%20-%20Augment%20Bounding%20Boxes.ipynb) from imgaug creators.
#
# We will create resize_imgaug() function that will take DataFrame as shown in the previous cell and apply resizing augmentation to the image and all corresponding bounding boxes. The function will return DataFrame with updated images and bounding boxes annotations.
#
# First, we visualize some of the operation that will take place in the resize_imgaug() function.

# %%
# start by groupping each image bounding boxes coordinates
# separate dataframes are formed based on the filename
grouped = labels_df.groupby('filename')

# %%
lbl1 = images_file[img1].split('/')[2]

# %%
# we can pull each group with get_group() using the filename
group_df = grouped.get_group(lbl1)
group_df = group_df.reset_index()
group_df = group_df.drop(['index'], axis=1)
group_df
# Out:
#                filename  width  height class  xmin  ymin  xmax  ymax
# 0  left_my_photo-67.jpg    640     480  left   261   142   417   278

# %% [markdown]
# ### Visualization of bounding boxes

# %%
# get bounding boxes coordinates from grouped data frame and write into array        
bb_array = group_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
# display the array we've got
bb_array
# Out:
# array([[261, 142, 417, 278]])

# %%
# pass the array of bounding boxes coordinates to the imgaug library
bbs = BoundingBoxesOnImage.from_xyxy_array(bb_array, shape=images[img1].shape)
# display the image and draw bounding boxes
ia.imshow(bbs.draw_on_image(images[img1], size=2))

# %% [markdown]
# ## skipping this for arrow dataset

# %%
arrow_resize = True

# %%
# to resize the images we create two augmenters
# one is used when the image height is more than 600px and the other when the width is more than 600px
if not arrow_resize:
    height_resize = iaa.Sequential([ 
        iaa.Resize({"height": 600, "width": 'keep-aspect-ratio'})
    ])

    width_resize = iaa.Sequential([ 
        iaa.Resize({"height": 'keep-aspect-ratio', "width": 600})
    ])

# %% [markdown]
# When we augment images using imgaug library it resizes the bounding boxes as well and return BoundingBoxesOnImage object.
# It looks like this:
# ```
# ['filename.jpg',
#  BoundingBoxesOnImage([BoundingBox(x1=81.1250, y1=114.5000, x2=324.8750, y2=320.7500, label=None)], shape=(337, 600, 3))]
# ```
# bbs_obj_to_df() function will convert BoundingBoxesOnImage object to data frame with xmin, ymin, xmax, ymax columns.

# %%
# function to convert BoundingBoxesOnImage object into DataFrame
def bbs_obj_to_df(bbs_object):
#     convert BoundingBoxesOnImage object into array
    bbs_array = bbs_object.to_xyxy_array()
#     convert array into a DataFrame ['xmin', 'ymin', 'xmax', 'ymax'] columns
    df_bbs = pd.DataFrame(bbs_array, columns=['xmin', 'ymin', 'xmax', 'ymax'])
    return df_bbs

# %% [markdown]
# Next, define resize_imgaug() function.
#
# It will take pandas DataFrame with ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax'] columns.
#
# And apply resizing augmentation to the image and all corresponding bounding boxes.
#
# The function will return DataFrame with updated images and bounding boxes annotations.
# resize_imgaug() function takes the following variables:
# - df: pandas DataFrame with ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax'] columns, labels_df in our case
# - images_path: path to the folder with original images, 'images/' in our case(don't forget the forward slash)
# - aug_images_path: path to the folder where augmented images will be stored, e.g. 'aug_images/' (the folder should be created in advance)
# - image_prefix:  prefix for augmented image filenames, e.g 'aug_'

# %%
def resize_imgaug(df, images_path, aug_images_path, image_prefix):
    # create data frame which we're going to populate with augmented image info
    aug_bbs_xy = pd.DataFrame(columns=
                              ['filename','width','height','class', 'xmin', 'ymin', 'xmax', 'ymax']
                             )
    grouped = df.groupby('filename')    
    
    for filename in df['filename'].unique():
    #   Get separate data frame grouped by file name
        group_df = grouped.get_group(filename)
        group_df = group_df.reset_index()
        group_df = group_df.drop(['index'], axis=1)
        
    #   The only difference between if and elif statements below is the use of height_resize and width_resize augmentors
    #   deffined previously.

    #   If image height is greater than or equal to image width 
    #   AND greater than 600px perform resizing augmentation shrinking image height to 600px.
        if group_df['height'].unique()[0] >= group_df['width'].unique()[0] and group_df['height'].unique()[0] > 600:
        #   read the image
            image = imageio.imread(images_path+filename)
        #   get bounding boxes coordinates and write into array        
            bb_array = group_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
        #   pass the array of bounding boxes coordinates to the imgaug library
            bbs = BoundingBoxesOnImage.from_xyxy_array(bb_array, shape=image.shape)
        #   apply augmentation on image and on the bounding boxes
            image_aug, bbs_aug = height_resize(image=image, bounding_boxes=bbs)
        #   write augmented image to a file
            imageio.imwrite(aug_images_path+image_prefix+filename, image_aug)  
        #   create a data frame with augmented values of image width and height
            info_df = group_df.drop(['xmin', 'ymin', 'xmax', 'ymax'], axis=1)        
            for index, _ in info_df.iterrows():
                info_df.at[index, 'width'] = image_aug.shape[1]
                info_df.at[index, 'height'] = image_aug.shape[0]
        #   rename filenames by adding the predifined prefix
            info_df['filename'] = info_df['filename'].apply(lambda x: image_prefix+x)
        #   create a data frame with augmented bounding boxes coordinates using the function we created earlier
            bbs_df = bbs_obj_to_df(bbs_aug)
        #   concat all new augmented info into new data frame
            aug_df = pd.concat([info_df, bbs_df], axis=1)
        #   append rows to aug_bbs_xy data frame
            aug_bbs_xy = pd.concat([aug_bbs_xy, aug_df])
            
    #   if image width is greater than image height 
    #   AND greater than 600px perform resizing augmentation shrinking image width to 600px
        elif group_df['width'].unique()[0] > group_df['height'].unique()[0] and group_df['width'].unique()[0] > 600:
        #   read the image
            image = imageio.imread(images_path+filename)
        #   get bounding boxes coordinates and write into array        
            bb_array = group_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
        #   pass the array of bounding boxes coordinates to the imgaug library
            bbs = BoundingBoxesOnImage.from_xyxy_array(bb_array, shape=image.shape)
        #   apply augmentation on image and on the bounding boxes
            image_aug, bbs_aug = width_resize(image=image, bounding_boxes=bbs)
        #   write augmented image to a file
            imageio.imwrite(aug_images_path+image_prefix+filename, image_aug)  
        #   create a data frame with augmented values of image width and height
            info_df = group_df.drop(['xmin', 'ymin', 'xmax', 'ymax'], axis=1)        
            for index, _ in info_df.iterrows():
                info_df.at[index, 'width'] = image_aug.shape[1]
                info_df.at[index, 'height'] = image_aug.shape[0]
        #   rename filenames by adding the predifined prefix
            info_df['filename'] = info_df['filename'].apply(lambda x: image_prefix+x)
        #   create a data frame with augmented bounding boxes coordinates using the function we created earlier
            bbs_df = bbs_obj_to_df(bbs_aug)
        #   concat all new augmented info into new data frame
            aug_df = pd.concat([info_df, bbs_df], axis=1)
        #   append rows to aug_bbs_xy data frame
            aug_bbs_xy = pd.concat([aug_bbs_xy, aug_df])

    #     append image info without any changes if it's height and width are both less than 600px 
        else:
            aug_bbs_xy = pd.concat([aug_bbs_xy, group_df])
    # return dataframe with updated images and bounding boxes annotations 
    aug_bbs_xy = aug_bbs_xy.reset_index()
    aug_bbs_xy = aug_bbs_xy.drop(['index'], axis=1)
    return aug_bbs_xy

# %%
# apply resizing augmentation to our images and write the updated images and bounding boxes annotations to the DataFrame 
# we will not apply prefix to our files and will overwrite images in the same directory
if not arrow_resize:
    resized_images_df = resize_imgaug(labels_df, '{}/'.format(img_src), '{}/'.format(img_src), '')
else:
    resized_images_df = labels_df

# %%
# display new DataFrame
resized_images_df
# Out:
#                       filename  width  height     class  xmin  ymin  xmax  \
# 0          left_my_photo-7.jpg    640     480      left   257   166   445
# 1         rotate_images_42.jpg    300     300     right   110    80   217
# 2    straight_my_photo-161.jpg    640     480  straight   281   190   453
# 3       right_my_photo-196.jpg    640     480     right    89    69   274
# 4         rotate_images_43.jpg    300     300     right    80    53   192
# 5       right_my_photo-128.jpg    640     480     right   295    95   453
# 6         rotate_images_13.jpg    300     300      left   105   113   231
# 7        right_my_photo-10.jpg    640     480     right   247   128   417
# 8       right_my_photo-100.jpg    640     480     right   379   172   550
# 9        rotate_images_113.jpg    300     300  straight    65    97   181
# 10       left_my_photo-177.jpg    640     480      left   265   294   436
# 11        rotate_images_29.jpg    300     300      left   126   116   195
# 12       right_my_photo-49.jpg    640     480     right   250    66   411
# 13        left_my_photo-40.jpg    640     480      left   390   104   549
# 14        left_my_photo-77.jpg    640     480      left   310    68   453
# 15        rotate_images_81.jpg    300     300  straight    96   129   187
# 16        rotate_images_97.jpg    300     300  straight    99   130   208
# 17       rotate_images_108.jpg    300     300  straight    56    68   210
# 18        left_my_photo-49.jpg    640     480      left   374   100   526
# 19        rotate_images_18.jpg    300     300      left    85   112   183
# 20    straight_my_photo-91.jpg    640     480  straight   276   206   450
# 21      right_my_photo-146.jpg    640     480     right   399    83   567
# 22        left_my_photo-27.jpg    640     480      left   277    49   433
# 23       right_my_photo-14.jpg    640     480     right    74    48   228
# 24      right_my_photo-138.jpg    640     480     right   244   275   414
# 25       left_my_photo-119.jpg    640     480      left   261   101   434
# 26      right_my_photo-134.jpg    640     480     right   231   171   387
# 27        left_my_photo-48.jpg    640     480      left   345     4   479
# 28      right_my_photo-108.jpg    640     480     right   251   219   423
# 29       left_my_photo-137.jpg    640     480      left   338    84   510
# ..                         ...    ...     ...       ...   ...   ...   ...
# 761   straight_my_photo-85.jpg    640     480  straight   197   286   386
# 762     right_my_photo-190.jpg    640     480     right   265   127   420
# 763   straight_my_photo-68.jpg    640     480  straight   372    14   521
# 764      left_my_photo-124.jpg    640     480      left   214     0   344
# 765  straight_my_photo-198.jpg    640     480  straight   288   120   449
# 766  straight_my_photo-112.jpg    640     480  straight   328    57   477
# 767       left_my_photo-94.jpg    640     480      left   367   110   539
# 768  straight_my_photo-116.jpg    640     480  straight   301    95   460
# 769      rotate_images_184.jpg    300     300      left    87   105   180
# 770        left_my_photo-4.jpg    640     480      left   296    66   455
# 771        rotate_images_4.jpg    300     300      left    89   121   193
# 772      right_my_photo-90.jpg    640     480     right   255    26   387
# 773  straight_my_photo-193.jpg    640     480  straight   232   267   398
# 774       rotate_images_34.jpg    300     300     right    67   112   169
# 775       rotate_images_40.jpg    300     300     right   118    97   220
# 776     right_my_photo-171.jpg    640     480     right   152   130   313
# 777      rotate_images_151.jpg    300     300     right    87    74   200
# 778   straight_my_photo-32.jpg    640     480  straight   283   184   437
# 779  straight_my_photo-104.jpg    640     480  straight   270    74   408
# 780       rotate_images_52.jpg    300     300     right    94   161   203
# 781       rotate_images_90.jpg    300     300  straight    47    93   144
# 782      right_my_photo-65.jpg    640     480     right   390    74   579
# 783     right_my_photo-148.jpg    640     480     right   280    92   423
# 784      left_my_photo-183.jpg    640     480      left   213   178   383
# 785   straight_my_photo-60.jpg    640     480  straight   496    33   635
# 786      left_my_photo-118.jpg    640     480      left   321    83   469
# 787      right_my_photo-37.jpg    640     480     right   259    38   394
# 788       left_my_photo-42.jpg    640     480      left   283   264   454
# 789       left_my_photo-64.jpg    640     480      left   307    50   450
# 790   straight_my_photo-87.jpg    640     480  straight   327   158   506
#
#      ymax
# 0     336
# 1     140
# 2     344
# 3     218
# 4     109
# 5     223
# 6     182
# 7     277
# 8     317
# 9     165
# 10    456
# 11    153
# 12    197
# 13    242
# 14    184
# 15    181
# 16    191
# 17    156
# 18    218
# 19    163
# 20    379
# 21    220
# 22    173
# 23    164
# 24    435
# 25    244
# 26    308
# 27    101
# 28    369
# 29    233
# ..    ...
# 761   451
# 762   254
# 763   136
# 764    90
# 765   261
# 766   179
# 767   258
# 768   220
# 769   152
# 770   191
# 771   178
# 772   131
# 773   419
# 774   167
# 775   151
# 776   252
# 777   131
# 778   333
# 779   191
# 780   222
# 781   145
# 782   227
# 783   210
# 784   329
# 785   152
# 786   212
# 787   144
# 788   420
# 789   166
# 790   319
#
# [791 rows x 8 columns]

# %%
# overwrite the labels.csv with updated info
if not arrow_resize:
    resized_images_df.to_csv(lbl_src, index=False)

# %%
# visualise the resized valentin-petkov-loL9nnBK-fE-unsplash.jpg image with bounding boxes
# to make sure our bounding boxes were resized correctly as well
grouped = resized_images_df.groupby('filename')
group_df = grouped.get_group(lbl1)
group_df = group_df.reset_index()
group_df = group_df.drop(['index'], axis=1)
bb_array = group_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
image = imageio.imread('{}/{}'.format(img_src, lbl1))
bbs = BoundingBoxesOnImage.from_xyxy_array(bb_array, shape=image.shape)
ia.imshow(bbs.draw_on_image(image, size=2))

# %% [markdown]
# ## 3. Augment images to upsample our dataset. Corresponding object bounding boxes should be augmented accordingly
#
# In this part we will learn how to perform image augmetations. To do so we slightly change our resize_imgaug() function. But first, let's assign augmentation we want to perfom.
#
# imgaug allows us to tune many cool parameters which you can read about in their [Documentation](https://imgaug.readthedocs.io/en/latest/source/augmenters.html).

# %%
# This setup of augmentation parameters will pick two of four given augmenters and apply them in random order
aug = iaa.SomeOf(2, [    
    iaa.Affine(scale=(0.5, 1.5)),
    iaa.Affine(rotate=(-45, 45)),
    iaa.Affine(translate_percent={"x": (-0.3, 0.3), "y": (-0.3, 0.3)}),
#     iaa.Fliplr(1),
    iaa.Add((-20, 20), per_channel=0.5),
    iaa.Multiply((0.5, 1.5)),
    iaa.GaussianBlur(sigma=(1.0, 3.0)),
    iaa.AdditiveGaussianNoise(scale=(0.03*255, 0.05*255))
])

# %% [markdown]
# Let's code image_aug() function.
#
# It takes the same variables as resize_imgaug(), plus:
# -augmenter: augmentation parameters of imgaug library. We can now apply custom augmenters.
#
# image_aug() function is very similar to resize_imgaug().
#
# But there's a caveat.
#
# Augmentations, like zooming in and translating the image in x/y directions, can lead to objects of interest (e'g', red pandas) partially or completely move out of image pane.
#
# image_aug() function will clip the bounding box if the object of interest is partially outside of image pane. And it will ignore image altogether if no bounding boxes left in image pane.

# %%
def image_aug(df, images_path, aug_images_path, num_aug, augmentor):
    # create data frame which we're going to populate with augmented image info
    aug_bbs_xy = pd.DataFrame(columns=['filename','width','height','class', 'xmin', 'ymin', 'xmax', 'ymax'])
    grouped = df.groupby('filename')
    
    for filename in df['filename'].unique():
        # get separate data frame grouped by file name
        group_df = grouped.get_group(filename)
        group_df = group_df.reset_index()
        group_df = group_df.drop(['index'], axis=1)   
    
        # read the image
        image = imageio.imread("{}/{}".format(images_path, filename))
    
        # get bounding boxes coordinates and write into array        
        bb_array = group_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
    
        # pass the array of bounding boxes coordinates to the imgaug library
        bbs = BoundingBoxesOnImage.from_xyxy_array(bb_array, shape=image.shape)
    
        for i in range(num_aug):
            # apply augmentation on image and on the bounding boxes
            image_aug, bbs_aug = augmentor(image=image, bounding_boxes=bbs)

            # disregard bounding boxes which have fallen out of image pane    
            bbs_aug = bbs_aug.remove_out_of_image()

            # clip bounding boxes which are partially outside of image pane
            bbs_aug = bbs_aug.clip_out_of_image()

            # don't perform any actions with the image if there are no bounding boxes left in it    
            if re.findall('Image...', str(bbs_aug)) == ['Image([]']:
                pass

            # otherwise continue
            else:
                # write augmented image to a file
                image_prefix = "{}_".format(i)
                aimg_name    = "{}/{}{}".format(aug_images_path, image_prefix, filename)
                imageio.imwrite(aimg_name, image_aug)  

                # create a data frame with augmented values of image width and height
                info_df = group_df.drop(['xmin', 'ymin', 'xmax', 'ymax'], axis=1)    
                for index, _ in info_df.iterrows():
                    info_df.at[index, 'width'] = image_aug.shape[1]
                    info_df.at[index, 'height'] = image_aug.shape[0]

                # rename filenames by adding the predifined prefix
                info_df['filename'] = info_df['filename'].apply(lambda x: image_prefix+x)

                # create a data frame with augmented bounding boxes coordinates using the function we created earlier
                bbs_df = bbs_obj_to_df(bbs_aug)

                # concat all new augmented info into new data frame
                aug_df = pd.concat([info_df, bbs_df], axis=1)

                # append rows to aug_bbs_xy data frame
                aug_bbs_xy = pd.concat([aug_bbs_xy, aug_df])            
    
    # return dataframe with updated images and bounding boxes annotations 
    aug_bbs_xy = aug_bbs_xy.reset_index()
    aug_bbs_xy = aug_bbs_xy.drop(['index'], axis=1)
    return aug_bbs_xy

# %%
# Apply augmentation to our images and save files into 'aug_images/' folder with 'aug1_' prefix.
# Write the updated images and bounding boxes annotations to the augmented_images_df dataframe.
augmented_images_df = image_aug(resized_images_df, img_src, aug_des, n_aug, aug)

# %%
# display new dataframe
augmented_images_df

# %% [markdown]
# Here using techniques described above to compare original resized images and augmented copies. We will draw bounding boxes as well to make sure they were augmented correctly.

# %%
grouped_resized   = resized_images_df.groupby('filename')
grouped_augmented = augmented_images_df.groupby('filename')

for filename in resized_images_df['filename'].unique():
    for i in range(n_aug):
        image_prefix = "{}_".format(i)
    
        group_r_df = grouped_resized.get_group(filename)
        group_r_df = group_r_df.reset_index()
        group_r_df = group_r_df.drop(['index'], axis=1)
        bb_r_array = group_r_df.drop(['filename', 'width', 'height', 'class'], axis=1).values
        resized_img = imageio.imread('{}/{}'.format(img_src, filename))
        bbs_r = BoundingBoxesOnImage.from_xyxy_array(bb_r_array, shape=resized_img.shape)

        group_a_df = grouped_augmented.get_group('{}_{}'.format(i, filename))
        group_a_df = group_a_df.reset_index()
        group_a_df = group_a_df.drop(['index'], axis=1)
        bb_a_array = group_a_df.drop(['filename', 'width', 'height', 'class'], axis=1).values

        augmented_img = imageio.imread('{}/{}{}'.format(aug_des, image_prefix, filename))
        bbs_a = BoundingBoxesOnImage.from_xyxy_array(bb_a_array, shape=augmented_img.shape)

        ia.imshow(np.hstack([
                bbs_r.draw_on_image(resized_img, size=2),
                bbs_a.draw_on_image(augmented_img, size=2)
                ]))
        
    break

# %% [markdown]
# ## 4. Document augmented images' new sizes and bounding boxes' coordinates to a CSV file
#
# We have two pandas DataFrames:
# 1. resized_images_df - original resized images annotations
# 2. augmented_images_df - augmented images annotations
#
# Let's concat them together and save in a new all_labels.csv file. After that we can put all the images in one folder.

# %%
# Concat resized_images_df and augmented_images_df together and save in a new all_labels.csv file
all_labels_df = pd.concat([resized_images_df, augmented_images_df])

all_labels_df.to_csv(all_lbl, index=False)

# %%
# Lastly we can copy all our augmented images in the same folder as original resized images

images_file = glob.glob('{}/*.jpg'.format(img_src))
for file in tqdm(images_file):
    dest_file = file.split('/')[2]
    shutil.copy(file, "{}/{}".format(all_img, dest_file))

images_file = glob.glob('{}/*.jpg'.format(aug_des))
for file in tqdm(images_file):
    dest_file = file.split('/')[2]
    shutil.copy(file, "{}/{}".format(all_img, dest_file))
